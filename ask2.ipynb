# %%
# !python3 ask2.py mri.png out2_1.png 0 2 0 -2 0 0
# !python3 ask2.py mri.png out2_2.png 0 2 0 -2 1 0
# !python3 ask2.py mri.png out2_3.png 2 1 0 0 2 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

f = np.array(Image.open('mri.png'))
plt.imshow(f, cmap="gray")
plt.show()

# %% [markdown]
# # Output for (α1 α2 α3 α4 α5 α6) = (0 2 0 -2 0 0)

# %%
f = np.array(Image.open('out2_1.png'))
plt.imshow(f, cmap="gray")
plt.show()

# %% [markdown]
# # Output for (α1 α2 α3 α4 α5 α6) = (0 2 0 -2 1 0)

# %%
f = np.array(Image.open('out2_2.png'))
plt.imshow(f, cmap="gray")
plt.show()

# %% [markdown]
# # Output for (α1 α2 α3 α4 α5 α6) = (1.42 1.42 0 -0.71 2.13 0)

# %%
f = np.array(Image.open('out2_3.png'))
plt.imshow(f, cmap="gray")
plt.show()
