# %%
# !python3 ask1.py trikoupi6.png 28.png 28
# !python3 ask1.py trikoupi6.png 83.png 83
# !python3 ask1.py trikoupi6.png 115.png 115
# !python3 ask1.py trikoupi6.png 187.png 187
# !python3 ask1.py trikoupi6.png 233.png 233

# %% [markdown]
# ## Original Image

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

f = np.array(Image.open('trikoupi6.png'))
plt.imshow(f, cmap="gray")
plt.show()

# %% [markdown]
# ## Output for k=28

# %%
f = np.array(Image.open('28.png'))
plt.imshow(f, cmap="gray")
plt.show()

# %% [markdown]
# ## Output for k=83

# %%
f = np.array(Image.open('83.png'))
plt.imshow(f, cmap="gray")
plt.show()

# %% [markdown]
# ## Output for k=115

# %%
f = np.array(Image.open('115.png'))
plt.imshow(f, cmap="gray")
plt.show()

# %% [markdown]
# ## Output for k=187

# %%
f = np.array(Image.open('187.png'))
plt.imshow(f, cmap="gray")
plt.show()

# %% [markdown]
# ## Output for k=233

# %%
f = np.array(Image.open('233.png'))
plt.imshow(f, cmap="gray")
plt.show()
